# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_train = np.array([1.0,2.0])
y_train = np.array([300.0,500.0])
print(f'x_train = {x_train} ')
print(f'y_train = {y_train} ')
# Out:
# x_train = [1. 2.]
# y_train = [300. 500.]

# %%
# size of the training and testing datasets
m = x_train.shape[0]
print(f"The number of training examples is : {m}")
# Out:
# The number of training examples is : 2

# %%
# we are using x_i y_i to represent the training example, where i represents the index of the data
i = 0
x_i = x_train[i]
y_i = y_train[i]
print(f"(x_{i}, y_{i}) = ({x_i}, {y_i})")
# Out:
# (x_0, y_0) = (1.0, 300.0)

# %% [markdown]
# ## Predicting data using simple linear regression manually using formula for linear regression
# ### Formula to be used for linear regression: f_(w,b)(x_i) = w*x_i + b

# %%
# Plot the data points
plt.scatter(x_train, y_train, marker='+', c='r')
# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.show()

# %%
# for our unknown sample data we are taking 2 = 100 and b = 100
w = 100
b = 100
print(f"w: {w}")
print(f"b: {b}")
# Out:
# w: 100
# b: 100

# %%
# predicting for x_0 and x_1
def linearRegressionModel(x,w,b):
    m = x.shape[0]
    f_wb = np.zeros(m)
    for i in range(m):
        f_wb[i] = w * x[i] + b
    return f_wb

# %%
tmp_f_wb = linearRegressionModel(x_train,w,b)
# Plot our model prediction
plt.plot(x_train, tmp_f_wb, c='b',label='Our Prediction')

# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r',label='Actual Values')

# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()

# %%
w = 200                         
b = 100    
x_i = 1.2
cost_1200sqft = w * x_i + b    

print(f"${cost_1200sqft:.0f} thousand dollars")
# Out:
# $340 thousand dollars

# %%
tmp_f_wb = linearRegressionModel(x_train,w,b)
# Plot our model prediction
plt.plot(x_train, tmp_f_wb, c='b',label='Our Prediction')

# Plot the data points
plt.scatter(x_train, y_train, marker='x', c='r',label='Actual Values')

# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()

# %% [markdown]
# ### The second values of w and b fits our data but the first one does not. This is the task of linear regression, to figure out the correct gradient (well that is the overall idea, there is much more to play)
